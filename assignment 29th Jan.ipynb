# %% [markdown]
# 1. Who Developed Python programming language?
# Ans. Guido van Rossum
#
# 2. Which type of programming does Python support?
# Ans. Python supports multiple programming paradigms, including structured or procedural, object-oriented and functional programming.
#
# 3. Is python case sensitive when dealing with identifiers?
# Ans. Yes
#
# 4. What is the correct extension for python file?
# Ans. .py is the mainly used but there are other extensions as well like .pyz, .pyd, .pyw, .pyo, .pyc, .pyi etc
#
# 5. Is python code complied or interpreted?
# Ans. Python is an interpreted language and not a compiled one, although compilation is a step.
#
# 6. Name a few blocks of code to define in python language?
# Ans. Blocks of code are defined by indentation in python.
# Blocks of code examples are functions, if-else blocks, loop blocks etc.
#
# 7. State a character used to give single line comments in python?
# Ans. # is used for single line comments
#
# 8. Mention functions which can help us to find the version of python we are currently working on?
# Ans. A. Using sys module :
#             sys.version
#             sys.version_info
#      B. Using platform module
#              platform.python_version()
#      C. Command line :
#              pyhton --version
#              python -V
#
# 9. Python supports the creation of anonymous funtion at runtime using a contructor called __ ?
# Ans. lambda
#
# 10. What does pip stands for python?
# Ans. PIP is a package management system used to install and manage software packages written in Python. It stands for "preferred installer program" or "Pip Installs Packages".
#
# 11. Mention a few built in functions in python?
# Ans. str()	Returns a string object
#      sum()	Sums the items of an iterator
#      set()	Returns a new set object
#      type()	Returns the type of an object
#      print()	Prints to the standard output device
#      min()	Returns the smallest item in an iterable
#      max()	Returns the largest item in an iterable
#      len()	Returns the length of an object
#      list()	Returns a list
#
# 12. What is the maximum possible length of an identifier in python?
# Ans. Unlimited but for better readability 79 Characters as per PEP-8
#
# 13. What are the benefits of using python?
# Ans. 1. Presence of third-party modules
#      2. Extensive support libraries(NumPy for numerical calculations, Pandas for data analytics, etc.)
#      3. Open source and large active community base
#      4. Versatile, Easy to read, learn and write
#      5. User-friendly data structures
#      6. High-level language
#      7. Dynamically typed language(No need to mention data type based on the value assigned, it takes data type)
#      8. Object-Oriented and Procedural  Programming language
#      9. Portable and Interactive
#      10. Ideal for prototypes – provide more functionality with less coding
#      11. Highly Efficient(Python’s clean object-oriented design provides enhanced process control, and the language is equipped with excellent text processing and integration capabilities, as well as its own unit testing framework, which makes it more efficient.)
#      12. Internet of Things(IoT) Opportunities
#      13. Interpreted Language
#      14. Portable across Operating systems
#
# 14. How is memory managed in python?
# Ans. Memory management in Python involves a private heap containing all Python objects and data structures. The management of this private heap is ensured internally by the Python memory manager. Python also uses cycle-detecting garbage collector for memory management.
#
# 15. How to install python on Windows and set path variables?
# Ans. Python installers are available for windows that will install pythan on windows machine.
# To set path variables follow the below steps :
# a. Right-clicking This PC and going to Properties.
# b. Clicking on the Advanced system settings in the menu on the left.
# c. Clicking on the Environment Variables button on the bottom right.
# d. In the System variables section, selecting the Path variable and clicking on Edit. The next screen will show all the directories that are currently a part of the PATH variable.
# e. Clicking on New and entering Python’s install directory.
#
# 16. I

# %%
#afdsfkljafd
